# %%
DIR = 'flickr30k_images'

# %%
import tensorflow as tf
from keras.models import Model, load_model
from keras import layers
import keras.backend as K
import keras
import numpy as np
import os
import matplotlib.pyplot as plt
import pandas as pd
import re
import random
import cv2
import math
import vgg19
print(tf.version.VERSION)
# Out:
# Using TensorFlow backend.
# 2.1.0

# %%
## Load in training images

H,W,C = 224,224,3
train_images_list = os.listdir(DIR + '/flickr30k_images/')
sample_size = int(0.99*len(train_images_list))
train_images = np.zeros((len(train_images_list),H,W,C))
arange = np.array(np.arange(sample_size),dtype='int')

j = 0
for i in train_images_list:
    train_images[j] = np.array(cv2.resize(plt.imread(DIR + '/flickr30k_images/' + i),(H,W)))
    j = j+1

# %%
## Define vocabulary for GRU

start_tag = '<s>'
end_tag = '<e>'



def get_vocab(captions):
    '''
    Purpose: Define vocabulary from captions
    
    captions -- All image captions from training set
    
    Returns: The size of vocabulary, all sentences, and the forward and reverse dictionary for vocab index locations
    '''
    arr = []
    m = captions.shape[0]
    sentence = [None ] * m
    j  = 0
    for i in captions:
        i = i.lower()
        i = re.sub(' +',' ',i)
        i = start_tag + ' ' + i + ' ' + end_tag
        sentence[j] = i.split()
        j += 1
        arr = arr + i.split()
    arr = list(arr)
    set_arr = list(set(arr))
    new_set = list()
    for word in set_arr:
        if arr.count(word) > 10 or word == '<s>' or word == '<e>':
            new_set.append(word)
    arr = new_set
    arr.append('<OTHER>')
    vocab_size = len(arr)
    fwd_dict = {}
    rev_dict = {}
    j = 0
    for i in arr:
        fwd_dict[i] = j
        rev_dict[j] = i
        j += 1
    return vocab_size, sentence, fwd_dict, rev_dict

def images_map_caption(train_images_list, train_captions):
    '''
    Purpose: Map image indices to caption indices
    
    train_images_list -- List of training images
    train_captions -- List of training captions
    
    Returns: The captions in the same order as the train_images_list they belong to
    '''
    caption = []
    for i in train_images_list:
        caption.append(train_captions[train_captions['image_name'] == i]['comment'].iat[0])
    return caption

# %%
## Create Captions

train_captions = pd.read_csv(DIR + '/results.csv', delimiter='|')
train_captions.columns = ['image_name', 'comment_number', 'comment']
captions = np.array(images_map_caption(train_images_list[:sample_size], train_captions))

# %%
vocab_size, sentences, fwd_dict, rev_dict = get_vocab(captions)
print(vocab_size)

del train_captions, captions

## train_images = images to train on
## sentences = captions to train on
## vocab_size = total vocab
## fwd_dict = word->number and rev_dict = number->word in RNN
## Start word: <s>, End word: <e>
# Out:
# 1227

# %%
def build_model(): ##Input partial caption is word indexes
    '''
    Purpose: Build the GRU model to make image captions
    
    Returns: The GRU Model
    '''
    embedder = layers.Embedding(vocab_size, 1000)

    GRU = layers.GRU(
        vocab_size-1, activation='tanh', recurrent_activation='sigmoid', use_bias=True,
        kernel_initializer='glorot_uniform', recurrent_initializer='orthogonal',
        bias_initializer='zeros', kernel_regularizer=None, recurrent_regularizer=None,
        bias_regularizer=None, activity_regularizer=None, kernel_constraint=None,
        recurrent_constraint=None, bias_constraint=None, dropout=0.0,
        recurrent_dropout=0.0, implementation=2, return_sequences=False,
        return_state=False, go_backwards=False
        )

    img_v = layers.Input(shape=(None,1000))

    words_hot_encoding = layers.Input(shape=(None,))
    words_v = embedder(words_hot_encoding)

    gru_input = layers.concatenate([img_v,words_v],axis=1)
    gru_output = GRU(gru_input)
    output = layers.Softmax()(gru_output)

    return Model(inputs=[img_v,words_hot_encoding],outputs=output)

def build_model_experimental(): ##Input partial captial is hot-encoded numpy array
    '''
    Purpose: Build the GRU model to make image captions
    
    Returns: The GRU Model
    '''
    word_encoder = layers.Conv1D(image_attributes.shape[2],vocab_size,padding='valid')

    GRU = layers.GRU(
        vocab_size-1, activation='tanh', recurrent_activation='sigmoid', use_bias=True,
        kernel_initializer='glorot_uniform', recurrent_initializer='orthogonal',
        bias_initializer='zeros', kernel_regularizer=None, recurrent_regularizer=None,
        bias_regularizer=None, activity_regularizer=None, kernel_constraint=None,
        recurrent_constraint=None, bias_constraint=None, dropout=0.0,
        recurrent_dropout=0.0, implementation=2, return_sequences=False,
        return_state=False, go_backwards=False
        )

    img_v = layers.Input(shape=(None,1000))

    words_hot_encoding = layers.Input(shape=(None,vocab_size))
    words_v = word_encoder(words_hot_encoding)

    gru_input = layers.concatenate([img_v,words_v],axis=1)
    gru_output = GRU(gru_input)
    output = layers.Softmax()(gru_output)

    return Model(inputs=[img_v,words_hot_encoding],outputs=output)

# %%
## See if model already created. If so, use that model. If not, create a new model
model_path = "gru_model%i.h5" % (vocab_size)
if os.path.exists(model_path):
    GRU_Model = load_model(model_path)
else:
    GRU_Model = build_model()

# %%
## Define model and experiment with different learning rates

optimizer = keras.optimizers.Adam(learning_rate=0.00000005, beta_1=0.9, beta_2=0.999, amsgrad=False) 
##0.0001 <= lr <= 0.00001
loss_function = keras.losses.categorical_crossentropy

GRU_Model.compile(optimizer, loss=loss_function)
GRU_Model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, None)         0
# __________________________________________________________________________________________________
# input_1 (InputLayer)            (None, None, 1000)   0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 1000)   1228000     input_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, 1000)   0           input_1[0][0]
#                                                                  embedding_1[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 1227)         8201268     concatenate_1[0][0]
# __________________________________________________________________________________________________
# softmax_1 (Softmax)             (None, 1227)         0           gru_1[0][0]
# ==================================================================================================
# Total params: 9,429,268
# Trainable params: 9,429,268
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def nums_to_words(nums_array):
    '''
    Purpose: Given a num from vocabulary find corresponding word
    
    nums_array - Nums representing words in vocabulary
    
    Returns: Array representing words
    '''
    words_array = []
    for i in nums_array:
        if i in rev_dict:
            words_array.append(rev_dict[i])
    return words_array

def convert(s):
    '''
    Purpose: Give output sentence
    
    s - Array of strings not in sentence format
    
    Returns: Sentence from strings array
    '''
    new = ""   
    for i in range(len(s)):
        x = s[i]
        if x != '<s>' and x != '<e>':
            if i > 1 and s[i] != ',' and s[i] != '.':
                new += " "
            new += x
    return new 

def image_caption(test_number,image_attributes, n=5,max_length=20):
    '''
    Purpose: Utilize the GRU to predict the image caption
    
    test_number -- Indice within image_attributes of the image
    image_attributes -- Array of output from images fed into VGG-16
    n -- The number of top probability words you would like to keep when expanding most probable next words
    max_length -- Max length of the output sentence
    
    Returns: Predicted sentence from image
    '''
    done = False

    ##Make top 5 array with 5 [sentence, score] where score is the sum of softmax probabilities of all words in sentence so far.
    ##Initialize the array with the top 5 combinations after the start word, <s>
    ##Sort top 5 by probability scores
    ##Continue to expand from top of top 5 until you reach the case that they all end with <e>
    ##When expanding sentence, expand to its top 5. Compare all 5 with minimum scores in current top 5. Replace as necessary.
    ##Re-sort top 5 and continue to expand
    topn_words = np.array([fwd_dict['<s>']])
    topn_scores = np.array([1.0])


    init_pred = GRU_Model.predict(x=[image_attributes[test_number][np.newaxis],topn_words[np.newaxis]]).reshape((-1,))
    topn_words = topn_words[np.newaxis,:] + np.zeros((n,topn_words.shape[0]))
    topn_scores = topn_scores[np.newaxis,:] + np.zeros((n,1))

    topn_words = np.concatenate((topn_words,init_pred.argsort()[-n:][::-1][:,np.newaxis]),axis=1).tolist() ##shape = [5][sentencelength]
    topn_scores = topn_scores * np.sort(init_pred)[-n:][::-1].reshape((-1,1)) ##shape = 5

    while done == False:
        done = True
        for i in range(len(topn_words)):
            num_words = np.array(topn_words[i])
            num_scores = topn_scores[i]
            if num_words.shape[0] <= max_length and num_words[-1] != fwd_dict['<e>']:
                
                init_pred = GRU_Model.predict(x=[image_attributes[test_number][np.newaxis],num_words[np.newaxis]]).reshape((-1,))
                num_words = num_words[np.newaxis,:] + np.zeros((n,num_words.shape[0]))
                num_scores.reshape((-1,1))
                num_scores = (num_scores[np.newaxis,:] + np.zeros((n,1)))

                num_words = np.concatenate((num_words,init_pred.argsort()[-n:][::-1][:,np.newaxis]),axis=1).tolist() ##shape = [5][sentencelength]
                num_scores = num_scores * np.sort(init_pred)[-n:][::-1].reshape((-1,1)) ##shape = 5

                topn_words[i] = num_words[0]
                topn_scores[i] = num_scores[0]
                for j in range(1,len(num_words),1):
                    for k in range(0,len(topn_words),1):
                        if num_scores[j] > topn_scores[k]:
                            topn_words[k] = num_words[j]
                            topn_scores[k] = num_scores[j]
                            break
        for i in range(len(topn_words)):
            sentence = np.array(topn_words[i])
            if sentence.shape[0] <= max_length and sentence[-1] != fwd_dict['<e>']:
                done = False
                break
    testsentence = topn_words[np.argmax(topn_scores)]
    return convert(nums_to_words(testsentence))

# %%
## Track epoch and batch number so training can be resumed if paused.

epoch_tracker = 0
batch_tracker = 0

# %%
## Train the GRU

epochs = 100
batch_size = 20
save_frequency_batch = 5
save_frequency_epoch = 1
save_model_batch_to = "gru_model%i.h5" % (vocab_size)
save_model_epoch_to = "gru_model2%i.h5" % (vocab_size)

test_number = 0
vgg = vgg19.Vgg19()
vgg.build(train_images[test_number:test_number+1].astype('float32'))
image_attributes_test = vgg.fc8.numpy().reshape((-1,1,1000)) ##image feature vector to feed into GRU

num_batches = int(math.ceil(sample_size/batch_size))
for j in range(epoch_tracker,epochs):
    if batch_tracker >= (num_batches-1):
        np.random.shuffle(arange)
        batch_tracker = 0
    epoch_tracker = j
    print("EPOCHS %i:" %(j))
    
    for batch in range(batch_tracker,num_batches):
        batch_tracker = batch
        s_i = int(batch*batch_size)
        e_i = s_i+batch_size
        vgg = vgg19.Vgg19()
        vgg.build(train_images[arange[s_i:e_i]].astype('float32'))
        image_attributes = vgg.fc8.numpy().reshape((-1,1,1000)) ##image feature vector to feed into GRU
        i = 0
        loss = []
        sentence_loss = []
        print(image_caption(test_number,image_attributes,n=3,max_length=10))
        target = np.zeros((1,vocab_size))
        for k in arange[s_i:e_i]:
            sentence = sentences[k]
            if sentence_loss != []:
                loss.append(np.mean(np.array(sentence_loss)))
                del sentence_loss
            sentence_loss = []
            if sentence == None:
                continue
            words = []
            for word in sentence:
                if word in fwd_dict:
                    target[:,fwd_dict[word]] = 1
                else:
                    target[:,fwd_dict['<OTHER>']] = 1
                if word != '<s>':
                    sentence_loss.append(GRU_Model.train_on_batch(x=[image_attributes[i][np.newaxis],np.array(words)[np.newaxis]],y=target))
                words.append(fwd_dict[word])
                if word in fwd_dict:
                    target[:,fwd_dict[word]] = 0
                else:
                    target[:,fwd_dict['<OTHER>']] = 0
            i = i+1
        del image_attributes
        print("batch_loss = %f" %(np.mean(np.array(loss))))
        if batch%save_frequency_batch == 0:
            GRU_Model.save(save_model_batch_to)
    if (j%save_frequency_epoch) == 0:
        print("Saving Model...")
        GRU_Model.save(save_model_epoch_to)
        print("Done Saving Model")
# Out:
# EPOCHS 4:
# the top in black shirt standing outside in some.
# batch_loss = 5.706437
# an older man sitting in the man sitting on some.
# batch_loss = 5.782820
# an older man sitting in the man sitting on some.
# batch_loss = 5.725204
# an older man sitting in the man sitting on some.
# batch_loss = 5.756696
# men wearing a girl wearing blue shirt standing outside in some.
# batch_loss = 5.913196
# people in a girl wearing blue shirt standing outside in some.
# batch_loss = 5.765370
# a girl sitting in the camera.
# batch_loss = 5.820151
# a girl sitting in the camera.
# batch_loss = 5.717189
# a girl sitting in the camera.
# batch_loss = 5.740940
# a girl sitting in the camera.
# batch_loss = 5.739653
# a girl sitting in the camera.
# batch_loss = 5.799415
# a girl sitting in the camera.
# batch_loss = 5.777284
# a girl sitting in the camera.
# batch_loss = 5.727572
# a girl sitting in the camera.
# batch_loss = 5.772448
# a girl sitting in the camera.
# batch_loss = 5.739675
# a girl sitting in the camera.
# batch_loss = 5.755049
# a girl sitting in the camera.
# batch_loss = 5.745996
# a girl sitting in the camera.
# batch_loss = 5.722633
# a girl sitting in the camera.
# batch_loss = 5.801438
# a girl sitting in the camera.
# batch_loss = 5.778596
# a girl sitting in the camera.
# batch_loss = 5.782212
# an older man in front.
# batch_loss = 5.761868
# an older man in front.
# batch_loss = 5.760005
# an older man in front.
# batch_loss = 5.693104
# an older man in front.
# batch_loss = 5.824275
# an older man in front.
# batch_loss = 5.813083
# an older man in front.
# batch_loss = 5.732588
# an older man in front.
# batch_loss = 5.782990
# an older man in front.
# batch_loss = 5.666689
# an older man in front.
# batch_loss = 5.790974
# an older man in front.
# batch_loss = 5.732222
# an older man in front.
# batch_loss = 5.803374
# an older man in front.
# batch_loss = 5.846457
# an older man in front.
# batch_loss = 5.777433
# an older man in front.
# batch_loss = 5.773597
# an older man in front.
# batch_loss = 5.809192
# vests in the ball, in some.
# batch_loss = 5.760125
# vests in the ball, in some.
# batch_loss = 5.843057
# vests in the ball, in some.
# batch_loss = 5.795630
# vests in the ball, in some.
# batch_loss = 5.769743
# vests in the ball, in some.
# batch_loss = 5.755972
# vests in the ball, in some.
# batch_loss = 5.726969
# vests in the ball, in some.
# batch_loss = 5.842007
# vests in the ball, in some.
# batch_loss = 5.760127
# vests in the ball, in some.
# batch_loss = 5.699572
# an older woman is sitting on some.
# batch_loss = 5.767885
# an older woman is sitting on some.
# batch_loss = 5.686637
# an older woman is sitting on some.
# batch_loss = 5.785396
# one man with two men sitting on his hands.
# batch_loss = 5.791757
# an older woman is sitting on some.
# batch_loss = 5.908470
# an older woman is sitting on some.
# batch_loss = 5.728453
# one man standing outside in the camera.
# batch_loss = 5.746373
# a girl in some, wearing blue shirt standing outside in front
# batch_loss = 5.774142
# a girl in some, wearing blue shirt standing outside in front
# batch_loss = 5.728378
# a girl in front of her hands in some.
# batch_loss = 5.741333
# a girl in some, wearing blue shirt standing outside in front
# batch_loss = 5.755438
# an older woman is sitting on some.
# batch_loss = 5.755833
# one man with her hand in blue shirt in front.
# batch_loss = 5.696543
# one man standing outside in the camera.
# batch_loss = 5.824401
# an older woman sitting in the camera.
# batch_loss = 5.795023
# an older woman sitting in the camera.
# batch_loss = 5.786610
# vests in the ball, in some.
# batch_loss = 5.713130
# vests in the ball, in some.
# batch_loss = 5.751853
# vests in the ball, in some.
# batch_loss = 5.742239
# one man standing outside in the camera.
# batch_loss = 5.781182
# men wearing a girl wearing blue shirt standing outside in some.
# batch_loss = 5.729525
# men wearing a girl wearing blue shirt standing outside in some.
# batch_loss = 5.785864
# men wearing a girl wearing blue shirt standing outside in some.
# batch_loss = 5.799425
# men wearing a girl wearing blue shirt standing outside in some.
# batch_loss = 5.776013
# vests in front of the camera.
# batch_loss = 5.728936
# vests in front of the camera.
# batch_loss = 5.658637
# vests in front of the camera.
# batch_loss = 5.793243
# vests in front of the camera.
# batch_loss = 5.778800
# vests in front of the man standing outside in some.
# batch_loss = 5.816093
# vests in front of the man standing outside in some.
# batch_loss = 5.740836
# vests in front of the camera.
# batch_loss = 5.748738
# grass in the camera, in blue shirt in his hands.
# batch_loss = 5.787085
# grass in the camera, in blue shirt in his hands.
# batch_loss = 5.840910
# the camera in the ball, in front.
# batch_loss = 5.757409
# vests in front of the camera.
# batch_loss = 5.777530
# three young woman standing outside in some.
# batch_loss = 5.782475
# the camera in the ball, in front.
# batch_loss = 5.784229
# three young woman standing outside in some.
# batch_loss = 5.771685
# three young woman standing outside in some.
# batch_loss = 5.811892
# the other in front.
# batch_loss = 5.728308
# the other in front.
# batch_loss = 5.766795
# the other in front.
# batch_loss = 5.842288
# the other in front.
# batch_loss = 5.867064
# the other in front.
# batch_loss = 5.704160
# the other in front.
# batch_loss = 5.729144
# the other in front.
# batch_loss = 5.776940
# the other in front.
# batch_loss = 5.780373
# the other in front.
# batch_loss = 5.727347
# vests in front of the camera.
# batch_loss = 5.729887
# vests in front of the camera.
# batch_loss = 5.810546
# the other in front.
# batch_loss = 5.778387
# the other in front.
# batch_loss = 5.788281
# the other in front.
# batch_loss = 5.736343
# the other in front.
# batch_loss = 5.702765
# the other in front.
# batch_loss = 5.776620
# two men in front.
# batch_loss = 5.689398
# two men in front.
# batch_loss = 5.760837
# the other in front.
# batch_loss = 5.680547
# the other in front.
# batch_loss = 5.725258
# the other in front.
# batch_loss = 5.714680
# the other in front.
# batch_loss = 5.790400
# the other in front.
# batch_loss = 5.845275
# the other in front.
# batch_loss = 5.731370
# two men in front of the ball.
# batch_loss = 5.739562
# the other in front.
# batch_loss = 5.697392
# the other in front.
# batch_loss = 5.771283
# a girl sitting in front.
# batch_loss = 5.754124
# the other in front.
# batch_loss = 5.732687
# a girl sitting in front.
# batch_loss = 5.708853
# a girl sitting in front.
# batch_loss = 5.790859
# a girl sitting in front.
# batch_loss = 5.769975
# a girl sitting in front.
# batch_loss = 5.797454
# a girl sitting in front.
# batch_loss = 5.761267
# a girl sitting in front.
# batch_loss = 5.684399
# a girl sitting in front.
# batch_loss = 5.786819
# a girl sitting in front.
# batch_loss = 5.788672
# a girl sitting in front.
# batch_loss = 5.792360
# a girl sitting in front.
# batch_loss = 5.746460
# a girl sitting in front.
# batch_loss = 5.716303
# two men in front.
# batch_loss = 5.727705
# two men in front.
# batch_loss = 5.823390
# three young woman standing outside in the camera.
# batch_loss = 5.794449
# the other in front of the camera in some.
# batch_loss = 5.839064
# the side of a girl in his hands.
# batch_loss = 5.762284
# three young woman standing outside in the other in some.
# batch_loss = 5.880221
# the other in front of the camera in some.
# batch_loss = 5.726184
# the other in front of the camera in some.
# batch_loss = 5.746526
# the other in front of him.
# batch_loss = 5.845767
# the other in front of him.
# batch_loss = 5.724416
# the other in front of him.
# batch_loss = 5.802532
# the other in front of him.
# batch_loss = 5.760539
# the other in front of the camera in some.
# batch_loss = 5.779171
# the other in front of the camera in some.
# batch_loss = 5.798206
# the other in front of the camera in some.
# batch_loss = 5.766673
# the other in front of him.
# batch_loss = 5.772659
# the other in front of him.
# batch_loss = 5.708825
# vests in front of the camera.
# batch_loss = 5.807735
# the other in front.
# batch_loss = 5.747565
# the other in front.
# batch_loss = 5.829398
# the other in front.
# batch_loss = 5.855760
# two men in front.
# batch_loss = 5.715910
# vests in front of the camera.
# batch_loss = 5.796197
# the other in front.
# batch_loss = 5.671568
# grass in front of the camera.
# batch_loss = 5.733935
# grass in front of the camera.
# batch_loss = 5.725440
# the side of a girl wearing blue shirt standing outside.
# batch_loss = 5.828753
# the other in front.
# batch_loss = 5.770292
# the other in front.
# batch_loss = 5.745453
# the other in front.
# batch_loss = 5.834888
# vests in front of the camera.
# batch_loss = 5.718860
# the other in front of him.
# batch_loss = 5.803278
# the other in front of him.
# batch_loss = 5.800397
# vests in front of the camera.
# batch_loss = 5.840181
# the other in front of him.
# batch_loss = 5.783237
# the other in front of him.
# batch_loss = 5.803159
# the other in front of him.
# batch_loss = 5.774843
# one man in front of her head in the camera.
# batch_loss = 5.794926
# the other in front.
# batch_loss = 5.758760
# the other in front.
# batch_loss = 5.724674
# vests in front of the camera.
# batch_loss = 5.787210
# vests in front of the camera.
# batch_loss = 5.708389
# the other in front.
# batch_loss = 5.761241
# three men wearing a girl and a girl sitting on some.
# batch_loss = 5.831316
# the other in front.
# batch_loss = 5.842399
# the other in front.
# batch_loss = 5.703945
# three men wearing a girl and a girl sitting on some.
# batch_loss = 5.831899
# the side of a girl wearing blue shirt standing outside.
# batch_loss = 5.774466
# three young woman sitting on some.
# batch_loss = 5.792674
# three young woman sitting on some.
# batch_loss = 5.777200
# three young woman sitting on some.
# batch_loss = 5.762273
# three young woman sitting on some.
# batch_loss = 5.809554
# three young woman sitting on some.
# batch_loss = 5.736860
# two men wearing a girl wearing blue shirt standing outside in front.
# batch_loss = 5.761983
# three young woman sitting on some.
# batch_loss = 5.766385
# three men in the ball, in front.
# batch_loss = 5.821676
# the side of a girl wearing blue shirt standing outside in front
# batch_loss = 5.761555
# two men wearing a girl wearing blue shirt standing outside in some.
# batch_loss = 5.784631
# vests in front of the side of the ball.
# batch_loss = 5.779377
# vests in front of the side of the ball.
# batch_loss = 5.712727
# vests in front of the side of the ball.
# batch_loss = 5.784255
# vests in front of the side of the ball.
# batch_loss = 5.799249
# the side of a girl wearing blue shirt standing outside in front.
# batch_loss = 5.697908
# vests in front of the camera.
# batch_loss = 5.734662
# vests in front of the camera.
# batch_loss = 5.717177
# vests in front of the camera.
# batch_loss = 5.738331
# vests in front of the camera.
# batch_loss = 5.733469
# vests in front of the camera.
# batch_loss = 5.766160
# vests in front of the camera.
# batch_loss = 5.768785
# vests in front of the camera.
# batch_loss = 5.783723
# vests in front of the camera.
# batch_loss = 5.772983
# vests in front of the camera.
# batch_loss = 5.858812
# three young woman sitting on some.
# batch_loss = 5.770095
# vests in front of the camera.
# batch_loss = 5.849531
# vests in front of the camera.
# batch_loss = 5.782825
# vests in front of the camera.
# batch_loss = 5.714538
# vests in front of the camera.
# batch_loss = 5.653360
# vests in front of the camera.
# batch_loss = 5.802403
# one man is a girl in his hands.
# batch_loss = 5.784132
# the other in front.
# batch_loss = 5.797415
# the other in front.
# batch_loss = 5.804075
# three young woman is sitting on some.
# batch_loss = 5.727118
# one man is a girl in his hands.
# batch_loss = 5.815922
# three young woman is sitting on some.
# batch_loss = 5.690115
# three young woman is sitting on some.
# batch_loss = 5.710019
# three young woman is sitting on some.
# batch_loss = 5.755446
# three young woman is sitting on some.
# batch_loss = 5.764184
# three men wearing a girl and a girl sitting on some.
# batch_loss = 5.768370
# a girl sitting in front.
# batch_loss = 5.796256
# two men wearing a girl wearing blue shirt standing outside in some.
# batch_loss = 5.759916
# two men wearing a girl wearing blue shirt standing outside in some.
# batch_loss = 5.800985
# a girl sitting in front.
# batch_loss = 5.718903
# two men wearing a girl wearing blue shirt standing outside in some.
# batch_loss = 5.763849
# two men wearing a girl wearing blue shirt standing outside in some.
# batch_loss = 5.780130
# vests in front of the camera.
# batch_loss = 5.695226
# vests in front of the camera.
# batch_loss = 5.787366
# vests in front of the camera.
# batch_loss = 5.794104
# vests in front of the camera.
# batch_loss = 5.743840
# vests in front of the camera.
# batch_loss = 5.727513
# vests in front of the camera.
# batch_loss = 5.716122
# three young woman sitting on some.
# batch_loss = 5.819657
# vests in front of the camera.
# batch_loss = 5.835537
# three young woman is sitting on some.
# batch_loss = 5.856852
# two men wearing a girl wearing blue shirt standing outside in some.
# batch_loss = 5.821134
# three men wearing a girl and a girl sitting on some.
# batch_loss = 5.778694
# vests in front of the camera.
# batch_loss = 5.793016
# vests in front of the camera.
# batch_loss = 5.737306
# three young woman is sitting on some.
# batch_loss = 5.878617
# three young woman is sitting on some.
# batch_loss = 5.724210
# vests in front of the camera.
# batch_loss = 5.790240
# vests in front of the camera.
# batch_loss = 5.680073
# vests in front of the camera.
# batch_loss = 5.670950
# the man a girl sitting in some of him.
# batch_loss = 5.793076
# the man a girl sitting in some of him.
# batch_loss = 5.767984
# three young woman standing outside in the camera.
# batch_loss = 5.728989
# two men wearing a girl wearing blue shirt standing outside in some.
# batch_loss = 5.681241
# three young woman standing outside in the camera.
# batch_loss = 5.798331
# three young woman standing outside in the camera.
# batch_loss = 5.685228
# three young woman standing outside in the camera.
# batch_loss = 5.768075
# two men wearing a girl wearing blue shirt standing outside in some.
# batch_loss = 5.848457
# two young woman in his hand in front of him.
# batch_loss = 5.745957
# vests in front of the camera.
# batch_loss = 5.778803
# the side of a girl wearing blue shirt standing outside in front
# batch_loss = 5.820184
# the side of a girl wearing blue shirt standing outside in front
# batch_loss = 5.792995
# two men wearing a girl wearing blue shirt standing outside in some.
# batch_loss = 5.752535
# two young woman in his hand in front of him.
# batch_loss = 5.752226
# two men wearing a girl wearing blue shirt standing outside in some.
# batch_loss = 5.748898
# a girl sitting in the camera.
# batch_loss = 5.731032
# a girl sitting in the camera.
# batch_loss = 5.734291
# a girl sitting in the camera.
# batch_loss = 5.770481
# a girl sitting in the camera.
# batch_loss = 5.780628
# a girl sitting in the camera.
# batch_loss = 5.822567
# a girl sitting in the camera.
# batch_loss = 5.696176
# a girl sitting in the camera.
# batch_loss = 5.733942
# a girl sitting in the camera.
# batch_loss = 5.841503
# a girl sitting in the camera.
# batch_loss = 5.737156
# a girl sitting in the camera.
# batch_loss = 5.831458
# a girl sitting in front.
# batch_loss = 5.713960
# a girl sitting in front.
# batch_loss = 5.778831
# a girl sitting in front.
# batch_loss = 5.824556
# a girl sitting in front.
# batch_loss = 5.870740
# a girl sitting in front.
# batch_loss = 5.813054
# a girl sitting in front.
# batch_loss = 5.800833
# a girl sitting in front.
# batch_loss = 5.781179
# a girl sitting in front.
# batch_loss = 5.754922
# a girl sitting in front.
# batch_loss = 5.787769
# a girl sitting in front.
# batch_loss = 5.770340
# a girl sitting in front.
# batch_loss = 5.751635
# a girl sitting in the camera.
# batch_loss = 5.736272
# a girl sitting in front.
# batch_loss = 5.764843
# a girl sitting in front.
# batch_loss = 5.847280
# a girl sitting in front.
# batch_loss = 5.771414
# a girl sitting in front.
# batch_loss = 5.818738
# a girl sitting in front.
# batch_loss = 5.738481
# a girl sitting in front.
# batch_loss = 5.779543
# a girl sitting in front.
# batch_loss = 5.759300
# a girl sitting in front.
# batch_loss = 5.714478
# a girl sitting in front.
# batch_loss = 5.781000
# a girl sitting in front.
# batch_loss = 5.817049
# three men in some vests in his hands.
# batch_loss = 5.865709
# one man sitting on some.
# batch_loss = 5.829690
# one man sitting on some.
# batch_loss = 5.814213
# one man sitting on some.
# batch_loss = 5.781799
# one man sitting on some.
# batch_loss = 5.751873
# a girl sitting in front.
# batch_loss = 5.846585
# three men in some vests in his hands.
# batch_loss = 5.722113
# a girl sitting in front.
# batch_loss = 5.792682
# a girl sitting in front.
# batch_loss = 5.767428
# a girl sitting in front.
# batch_loss = 5.840629
# a girl sitting in front.
# batch_loss = 5.741877
# a girl sitting in front.
# batch_loss = 5.740427
# a girl sitting in front.
# batch_loss = 5.841394
# a girl sitting in front.
# batch_loss = 5.752421
# a girl in some shirt standing outside in some.
# batch_loss = 5.796179
# one man and a girl and a girl sitting on some.
# batch_loss = 5.827888
# one man and a girl and a girl sitting on some.
# batch_loss = 5.776001
# grass in the man standing outside in some.
# batch_loss = 5.772956
# grass in the man standing outside in some.
# batch_loss = 5.708560
# grass in the man standing outside in some.
# batch_loss = 5.856303
# a girl sitting in front.
# batch_loss = 5.786837
# grass in the man standing outside in blue shirt in his hand.
# batch_loss = 5.776104
# grass in the man standing outside in some.
# batch_loss = 5.749828
# three young woman standing outside in the ball.
# batch_loss = 5.760693
# three young woman standing outside in the ball.
# batch_loss = 5.759532
# three young woman standing outside in the ball.
# batch_loss = 5.760366
# vests in front of the camera.
# batch_loss = 5.858115
# vests in front of the camera.
# batch_loss = 5.750677
# one man sitting on some.
# batch_loss = 5.669383
# one man sitting on some.
# batch_loss = 5.775295
# men wearing a girl and a girl wearing a girl wearing blue shirt standing outside in some.
# batch_loss = 5.708018
# a girl sitting in front.
# batch_loss = 5.742118
# a girl sitting in front.
# batch_loss = 5.802041
# a girl sitting in front.
# batch_loss = 5.846277
# a girl sitting in front.
# batch_loss = 5.751039
# a girl sitting in front.
# batch_loss = 5.719232
# a girl sitting in front.
# batch_loss = 5.771067
# a girl sitting in front.
# batch_loss = 5.753055
# a girl sitting in front.
# batch_loss = 5.739889
# a girl sitting in front.
# batch_loss = 5.766407
# a girl sitting in front.
# batch_loss = 5.817355
# a girl sitting in front.
# batch_loss = 5.775723
# a girl sitting in front.
# batch_loss = 5.720222
# a girl sitting in front.
# batch_loss = 5.779736
# one man sitting on her hands.
# batch_loss = 5.855145
# a girl sitting in front.
# batch_loss = 5.749511
# a girl sitting in front.
# batch_loss = 5.733700
# a girl sitting in front.
# batch_loss = 5.762945
# a girl sitting in front.
# batch_loss = 5.774431
# a girl sitting in front.
# batch_loss = 5.854109
# vests in front of the camera.
# batch_loss = 5.743083
# vests in front of the camera.
# batch_loss = 5.762049
# vests in front of the camera.
# batch_loss = 5.857090
# a girl sitting in front.
# batch_loss = 5.756335
# a girl sitting in front.
# batch_loss = 5.800473
# vests in front of the camera.
# batch_loss = 5.751113
# a girl sitting in front.
# batch_loss = 5.714288
# a girl sitting in front.
# batch_loss = 5.802157
# a girl sitting in front.
# batch_loss = 5.871383
# a girl sitting in front.
# batch_loss = 5.671562
# vests in front of the camera.
# batch_loss = 5.703766
# a girl sitting in front.
# batch_loss = 5.754797
# vests in front of the camera.
# batch_loss = 5.687758
# grass in the man standing outside in some.
# batch_loss = 5.711689
# vests in front of the camera.
# batch_loss = 5.724016
# three young woman sitting on some.
# batch_loss = 5.775585
# vests in front of the camera.
# batch_loss = 5.817354
# vests in front of the camera.
# batch_loss = 5.689622
# three young woman sitting on some.
# batch_loss = 5.875391
# vests in front of the camera.
# batch_loss = 5.759136
# vests in front of the camera.
# batch_loss = 5.837637
# vests in front of the camera.
# batch_loss = 5.865319
# vests in front of the camera.
# batch_loss = 5.804142
# vests in front of the camera.
# batch_loss = 5.769005
# vests in front of the camera.
# batch_loss = 5.790240
# vests in front of the camera.
# batch_loss = 5.782762
# vests in front of the camera.
# batch_loss = 5.770072
# vests in front of the camera.
# batch_loss = 5.690844
# grass in the man standing outside in some.
# batch_loss = 5.762093
# grass in the man standing outside in some.
# batch_loss = 5.702084
# grass in the man standing outside in some.
# batch_loss = 5.852747
# vests in front of the camera.
# batch_loss = 5.863907
# three young woman sitting on some.
# batch_loss = 5.850783
# three young woman sitting on some.
# batch_loss = 5.752560
# three young woman sitting on some.
# batch_loss = 5.713206
# three young woman sitting on some.
# batch_loss = 5.885936
# vests in front of the camera.
# batch_loss = 5.766962
# three young woman sitting on some.
# batch_loss = 5.759042
# three young woman sitting on some.
# batch_loss = 5.789874
# vests in front of the camera.
# batch_loss = 5.757450
# grass in the man standing outside in some.
# batch_loss = 5.951526
# grass in the man standing outside in some.
# batch_loss = 5.799121
# vests in front of the camera.
# batch_loss = 5.777983
# vests in front of the camera.
# batch_loss = 5.920480
# a girl in some, wearing blue shirt standing outside with the other in some, in the camera,
# batch_loss = 5.753569
# vests in front of the camera.
# batch_loss = 5.775860
# vests in front of the camera.
# batch_loss = 5.747291
# vests in front of the camera.
# batch_loss = 5.820287
# vests in front of the camera.
# batch_loss = 5.752239
# vests in front of the camera.
# batch_loss = 5.782678
# a girl in some shirt standing outside in some.
# batch_loss = 5.769422
# a girl in some shirt standing outside in some.
# batch_loss = 5.733045
# a girl in some shirt standing outside in some.
# batch_loss = 5.835204
# a girl sitting in front.
# batch_loss = 5.808793
# a girl sitting in front.
# batch_loss = 5.685149
# a girl in some shirt standing outside in some.
# batch_loss = 5.681042
# a girl sitting in front.
# batch_loss = 5.762547
# a girl sitting in front.
# batch_loss = 5.780928
# a girl sitting in front.
# batch_loss = 5.749905
# a girl sitting in front
# batch_loss = 5.672400
# a girl sitting in front
# batch_loss = 5.772581
# a girl sitting in front
# batch_loss = 5.735512
# a girl sitting in front
# batch_loss = 5.785929
# a girl sitting in front
# batch_loss = 5.809255
# a girl sitting in front
# batch_loss = 5.845918
# a girl sitting in front
# batch_loss = 5.740338
# a girl sitting in front
# batch_loss = 5.756301
# a girl sitting in front
# batch_loss = 5.782779
# a girl sitting in front
# batch_loss = 5.698475
# a girl sitting in front
# batch_loss = 5.814070
# a girl sitting in front
# batch_loss = 5.785559
# a girl sitting in front
# batch_loss = 5.777225
# a girl sitting in front
# batch_loss = 5.800625
# a girl sitting in front
# batch_loss = 5.736691
# a girl sitting in front
# batch_loss = 5.705489
# a girl sitting in front
# batch_loss = 5.770593
# a girl sitting in front
# batch_loss = 5.739032
# a girl sitting in front
# batch_loss = 5.764696
# a girl sitting in front
# batch_loss = 5.810818
# a girl sitting in front
# batch_loss = 5.767120
# a girl sitting in front
# batch_loss = 5.831584
# a girl sitting in front
# batch_loss = 5.801326
# a girl sitting in front
# batch_loss = 5.759575
# a girl sitting in front
# batch_loss = 5.757425
# a girl sitting in front
# batch_loss = 5.867998
# men wearing a girl and a girl wearing a girl wearing blue shirt standing outside in some.
# batch_loss = 5.797049
# a girl in front of her hand in front.
# batch_loss = 5.729015
# vests in front of the camera.
# batch_loss = 5.710861
# three men wearing a girl wearing blue shirt standing outside in some.
# batch_loss = 5.730763
# three men wearing a girl wearing blue shirt standing outside in some.
# batch_loss = 5.712450
# a girl in front of her hand in front.
# batch_loss = 5.710420
# a girl in front of her hand in front.
# batch_loss = 5.762100
# three men wearing a girl wearing blue shirt standing outside in some.
# batch_loss = 5.834698
# three men wearing a girl wearing blue shirt standing outside in some.
# batch_loss = 5.811543
# three men wearing a girl wearing blue shirt standing outside in some.
# batch_loss = 5.763713
# people in the ball, in the ball on her hands.
# batch_loss = 5.796645
# people in the ball, in the ball on her hands.
# batch_loss = 5.812796
# people in the ball, in the ball on some.
# batch_loss = 5.746622
# a girl in front of her hand in front.
# batch_loss = 5.634732
# vests in front of the camera.
# batch_loss = 5.780618
# vests in front of the camera.
# batch_loss = 5.758241
# vests in front of the camera.
# batch_loss = 5.751538
# vests in front of the man sitting on a girl in front.
# batch_loss = 5.814009
# people in the ball, in the other in some, in some.
# batch_loss = 5.731870
# a girl sitting in front
# batch_loss = 5.798733
# a girl sitting in front
# batch_loss = 5.742769
# a girl sitting in front
# batch_loss = 5.713029
# a girl sitting in front
# batch_loss = 5.825239
# Saving Model...
# Done Saving Model
# EPOCHS 5:
# a girl sitting in front
# batch_loss = 5.737606
# a girl sitting in front
# batch_loss = 5.780745
# a girl sitting in front
# batch_loss = 5.741775
# a girl sitting in front.
# batch_loss = 5.838606
# vests in front of the man standing outside in some.
# batch_loss = 5.723327
# a girl sitting in front
# batch_loss = 5.761175
# a girl sitting in front
# batch_loss = 5.780336
# a girl sitting in front
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-159-9cbea6a1177c> in <module>
#      41                     target[:,fwd_dict[word]] = 1
#      42                     if word != '<s>':
# ---> 43                         sentence_loss.append(GRU_Model.train_on_batch(x=[image_attributes[i][np.newaxis],np.array(words)[np.newaxis]],y=target))
#      44                     words.append(fwd_dict[word])
#      45                     target[:,fwd_dict[word]] = 0
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1512             ins = x + y + sample_weights
#    1513         self._make_train_function()
# -> 1514         outputs = self.train_function(ins)
#    1515
#    1516         if reset_metrics:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3733     return nest.pack_sequence_as(
#    3734         self._outputs_structure,
# -> 3735         [x._numpy() for x in outputs],  # pylint: disable=protected-access
#    3736         expand_composites=True)
#    3737
#
# /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/keras/backend.py in <listcomp>(.0)
#    3733     return nest.pack_sequence_as(
#    3734         self._outputs_structure,
# -> 3735         [x._numpy() for x in outputs],  # pylint: disable=protected-access
#    3736         expand_composites=True)
#    3737
#
# /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/framework/ops.py in _numpy(self)
#     906     # pylint: disable=protected-access
#     907     try:
# --> 908       return self._numpy_internal()
#     909     except core._NotOkStatusException as e:
#     910       six.raise_from(core._status_to_exception(e.code, e.message), None)
#
# KeyboardInterrupt:

# %%
## Predict image captions

f, ax = plt.subplots(4,2)

test_number = train_images.shape[0]-30

if test_number < train_images.shape[0]-8:
    plt.imshow(np.array(train_images[test_number],dtype='uint8'))
    vgg = vgg19.Vgg19()
    vgg.build(train_images[test_number:test_number+9].astype('float32'))
    image_attributes = vgg.fc8.numpy().reshape((-1,1,1000)) ##image feature vector to feed into GRU
else:
    print("test_number is too large")



for i in range(2):
    a = int(i*4)
    ax[0,i].imshow(np.array(train_images[test_number+a],dtype='uint8'));  ax[0,i].axis('Off'); ax[0,i].set_title(image_caption(a,image_attributes,n=10), size=10);
    ax[1,i].imshow(np.array(train_images[test_number+a+1],dtype='uint8'));  ax[1,i].axis('Off'); ax[1,i].set_title(image_caption(a+1,image_attributes,n=10), size=10);
    ax[2,i].imshow(np.array(train_images[test_number+a+2],dtype='uint8'));  ax[2,i].axis('Off'); ax[2,i].set_title(image_caption(a+2,image_attributes,n=10), size=10);
    ax[3,i].imshow(np.array(train_images[test_number+a+3],dtype='uint8'));  ax[3,i].axis('Off'); ax[3,i].set_title(image_caption(a+3,image_attributes,n=10), size=10);
f.tight_layout(pad=0)
plt.show()
